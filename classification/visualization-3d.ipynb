# %%
import os, sys, glob, time
sys.path.append("../pyusct/")
from model import Conv_3d
from visualizer import Visualizer
from rfdata import RFdata
# Out:
# /root/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
LOCAL_PATH = "/mnt/nas/"
MODEL_DIR = os.path.join(LOCAL_PATH, "PYUSCT_model/")
DATA_DIR = os.path.join(LOCAL_PATH, "PYUSCT_train/")
scaler_path = os.path.join(MODEL_DIR, "Scaler/Log_MinMax_RFScaler_ds028.pickle")

# %%
model_path = os.path.join(MODEL_DIR, "clf/deep/dataset036_3d_lr_0.001_epoch_50_batchsize_32")

# %%
source_path = os.path.join(LOCAL_PATH, "nb_usctsim/sim_015/trial_001/")
model_params = os.path.join(model_path, "conv3d_raw_data_epoch_49.pth")

# %%
source = RFdata(source_path)
model = Conv_3d(scaler_path, model_params)
visualizer = Visualizer(source, model)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [raw]
# fig = plt.figure(figsize=(16,12))
# plt.imshow(visualizer.rf.medium_sct)

# %%
visualizer.extract_subimage(shape=[6, 4], batch_size=4)
# Out:
# 256 256
# 256 257
# 256 258
# 256 259
# predict point 3
# 257 256
# 257 257
# 257 258
# 257 259
# predict point 7
# 258 256
# 258 257
# 258 258
# 258 259
# predict point 11
# 259 256
# 259 257
# 259 258
# 259 259
# predict point 15
# 260 256
# 260 257
# 260 258
# 260 259
# predict point 19
# 261 256
# 261 257
# 261 258
# 261 259
# predict point 23
# [[-0.40576148  0.8035413   1.1989224  -1.9647566 ]
#  [ 1.4983262  -1.0491794   0.09659806 -0.81130576]
#  [-2.0841615  -0.9411167   0.91087085  1.6163564 ]
#  [-1.8142238   0.10317359  0.44800672  1.5428853 ]
#  [-0.19795434 -0.3086966  -1.8714472   1.8181751 ]
#  [-0.80277133 -1.5233501   0.32522324  2.1647153 ]]
# [-0.40576148  0.8035413   1.1989224  -1.9647566   1.4983262  -1.0491794
#   0.09659806 -0.81130576 -2.0841615  -0.9411167   0.91087085  1.6163564
#  -1.8142238   0.10317359  0.44800672  1.5428853  -0.19795434 -0.3086966
#  -1.8714472   1.8181751  -0.80277133 -1.5233501   0.32522324  2.1647153 ]
# [[-0.40576148  0.8035413   1.1989224  -1.9647566 ]
#  [ 1.4983262  -1.0491794   0.09659806 -0.81130576]
#  [-2.0841615  -0.9411167   0.91087085  1.6163564 ]
#  [-1.8142238   0.10317359  0.44800672  1.5428853 ]
#  [-0.19795434 -0.3086966  -1.8714472   1.8181751 ]
#  [-0.80277133 -1.5233501   0.32522324  2.1647153 ]]

# %%
visualizer.visualize_prob()

# %%
visualizer.visualize_01()
