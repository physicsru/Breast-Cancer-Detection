# %%
import os, json, glob, math
import numpy as np
import pandas as pd
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
% matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("./pyusct/")
from rfdata import RFdata
from randomSampleGenerator import RandomSampleGenerator

# %%
LOCAL_PATH = "/media/yuhui/dea78678-112b-4f0f-acbf-4e9d1be35e35/nas/"
MOUNT_PATH = "/run/user/1000/gvfs/smb-share:server=azlab-fs01,share=東研究室/個人work/富井/"

# %% [markdown]
# ####  Load trainer

# %%
SampleGenerator = RandomSampleGenerator(near_edge=True)

# %% [markdown]
# #### Generate data test

# %%
sim_path = os.path.join(MOUNT_PATH, "nb_usctsim/sim_015/")
output_path = os.path.join(LOCAL_PATH, "PYUSCT_train/dataset036/")

# %%
SampleGenerator.getRandomBalancedSampleFromSim(1000, sim_path, output_path)
# Out:
# 50 trials
# loading /run/user/1000/gvfs/smb-share:server=azlab-fs01,share=東研究室/個人work/富井/nb_usctsim/sim_015/trial_001
# trial_001 loaded
# generating near_neg set
# generated pos ndarray with shape=(11430, 2)
# generated near_neg ndarray with shape=(59467, 2)
# processing
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# Finished
# loading /run/user/1000/gvfs/smb-share:server=azlab-fs01,share=東研究室/個人work/富井/nb_usctsim/sim_015/trial_002
# trial_002 loaded
# generating near_neg set
# generated pos ndarray with shape=(10426, 2)
# generated near_neg ndarray with shape=(53926, 2)
# processing
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# Finished
# loading /run/user/1000/gvfs/smb-share:server=azlab-fs01,share=東研究室/個人work/富井/nb_usctsim/sim_015/trial_003
# trial_003 loaded
# generating near_neg set
# generated pos ndarray with shape=(10553, 2)
# generated near_neg ndarray with shape=(51687, 2)
# processing
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# ...
