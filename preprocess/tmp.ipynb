# %%
import os
import sys
import time
sys.path.append('pyusct/')
import numpy as np
from rfdata import RFdata
MOUNT_PATH = "/run/user/1000/gvfs/smb-share:server=azlab-fs01.local,share=東研究室/個人work/富井/"

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
rf = RFdata(os.path.join(MOUNT_PATH, "nb_usctsim/sim_009_wire/trial_001"))

# %%
rf.draw_input()

# %%
offsets = np.arange(-100, 100, 1)
_, subset = rf.getPointSubset((512,512), offsets)

# %%
subset.shape
# Out:
# (32, 256, 200)

# %%
sa = rf.syntheticAperture()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-2ddb45c29ed4> in <module>()
# ----> 1 sa = rf.syntheticAperture()
#
# ~/workspace/yuhui/pyusct/rfdata.py in syntheticAperture(self, c)
#     127             return np.sum(subset)
#     128
# --> 129         sa = np.array([gridwise_summation(ngrid) for ngrid in ngrids])
#     130         sa = np.log(sa.reshape( self.kgrid["Nx"]//c, self.kgrid["Ny"]//c ).T)
#     131         return sa
#
# ~/workspace/yuhui/pyusct/rfdata.py in <listcomp>(.0)
#     127             return np.sum(subset)
#     128
# --> 129         sa = np.array([gridwise_summation(ngrid) for ngrid in ngrids])
#     130         sa = np.log(sa.reshape( self.kgrid["Nx"]//c, self.kgrid["Ny"]//c ).T)
#     131         return sa
#
# ~/workspace/yuhui/pyusct/rfdata.py in gridwise_summation(ngrid)
#     124         ngrids = mesh_grid.reshape(2, mesh_grid.size//2).T
#     125         def gridwise_summation(ngrid):
# --> 126             _, subset = self.getPointSubset(ngrid*c)
#     127             return np.sum(subset)
#     128
#
# ~/workspace/yuhui/pyusct/rfdata.py in getPointSubset(self, ngrid, offset_arr, flg_mask)
#     111             RF = self.amp
#     112
# --> 113         subset = pairwise_extraction(RF, map_time_pos, offset_arr)
#     114
#     115         return map_time_pos, subset
#
# ~/workspace/yuhui/pyusct/rfdata.py in pairwise_extraction(RF, map_time_pos, offset_arr)
#     102                     pos = map_time_pos[i,j]
#     103                     ts = RF[i,j,:]
# --> 104                     ts = np.concatenate((ts, np.zeros_like(ts)))
#     105                     D[i,j,:] = ts[pos+offset_arr]
#     106             return D
#
# KeyboardInterrupt:
