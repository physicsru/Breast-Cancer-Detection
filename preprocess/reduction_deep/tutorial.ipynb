# %%
import torch

# %%
import os

import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import MNIST
from torchvision.utils import save_image

if not os.path.exists('./mlp_img'):
    os.mkdir('./mlp_img')


def to_img(x):
    x = 0.5 * (x + 1)
    x = x.clamp(0, 1)
    x = x.view(x.size(0), 1, 28, 28)
    return x


num_epochs = 100
batch_size = 128
learning_rate = 1e-3

img_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset = MNIST('./data', transform=img_transform, download=True)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)


class autoencoder(nn.Module):
    def __init__(self):
        super(autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(28 * 28, 128),
            nn.ReLU(True),
            nn.Linear(128, 64),
            nn.ReLU(True), 
            nn.Linear(64, 12),
            nn.ReLU(True),
            nn.Linear(12, 3)
        )
        self.decoder = nn.Sequential(
            nn.Linear(3, 12),
            nn.ReLU(True),
            nn.Linear(12, 64),
            nn.ReLU(True),
            nn.Linear(64, 128),
            nn.ReLU(True),
            nn.Linear(128, 28 * 28),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x


model = autoencoder().cuda()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=learning_rate, weight_decay=1e-5)

for epoch in range(num_epochs):
    for data in dataloader:
        img, _ = data
        # print(img.shape)
        img = img.view(img.size(0), -1)
        # print(img.shape)
        img = Variable(img).cuda()
        # print(img.shape)
        # break
        # ===================forward=====================
        output = model(img)
        loss = criterion(output, img)
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'
          .format(epoch + 1, num_epochs, loss.data[0]))
    if epoch % 10 == 0:
        pic = to_img(output.cpu().data)
        save_image(pic, './mlp_img/image_{}.png'.format(epoch))

torch.save(model.state_dict(), './sim_autoencoder.pth')
# Out:
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [1/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [2/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [3/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [4/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [5/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [6/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [7/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [8/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [9/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [10/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [11/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [12/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [13/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [14/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [15/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [16/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [17/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [18/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [19/100], loss:0.1240
# /home/yuhui/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/ipykernel_launcher.py:88: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [20/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [21/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [22/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [23/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [24/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [25/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [26/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [27/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [28/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [29/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [30/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [31/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [32/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [33/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [34/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [35/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [36/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [37/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [38/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [39/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [40/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [41/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [42/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [43/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [44/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [45/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [46/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [47/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [48/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [49/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [50/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [51/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [52/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [53/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [54/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [55/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [56/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [57/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [58/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [59/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [60/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [61/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [62/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [63/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [64/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [65/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [66/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [67/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [68/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [69/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [70/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [71/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [72/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [73/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [74/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [75/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [76/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [77/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [78/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [79/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [80/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [81/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [82/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [83/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [84/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [85/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [86/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [87/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [88/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [89/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [90/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [91/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [92/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [93/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [94/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [95/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [96/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [97/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [98/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [99/100], loss:0.1240
# torch.Size([128, 1, 28, 28])
# torch.Size([128, 784])
# torch.Size([128, 784])
# epoch [100/100], loss:0.1240
